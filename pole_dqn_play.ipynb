# %%
# !{os.sys.executable} -m pip install gymnasium
# !{os.sys.executable} -m pip install Pillow
# !{os.sys.executable} -m pip install ipython
# !{os.sys.executable} -m pip install pygame
# !{os.sys.executable} -m pip install torchsummary
# !{os.sys.executable} -m pip install tensorboardX

# %%
# Import useful packages

import os
import sys
import gymnasium as gym
import random
import numpy as np

import torch
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary

from DQN_Model import DQN
from DQN_Model_improved import DQN_improved
from tensorboardX import SummaryWriter

from collections import namedtuple, deque

# %%
import pygame
from pygame.locals import QUIT

# Initialize pygame
pygame.init()

def play_game_with_model(model_name, load_best = False):
    # Initialize the environment
    env = gym.make(env_name, render_mode="human")
    state = env.reset()[0]
    done = False
    
    # Load the model
    state_size = env.observation_space.low.size
    action_size = env.action_space.n
    loaded_online_net = DQN(state_size, action_size).to(device)
    if( not load_best):
        loaded_online_net.load_state_dict(torch.load(f'saved_models/{model_name}/online_net.pth'))
    else:
        loaded_online_net.load_state_dict(torch.load(f'saved_models/{model_name}/best_online_net.pth'))
    loaded_online_net.eval()  # Set the model to evaluation mode


    # Initialize the display
    screen = pygame.display.set_mode((600, 400))
    pygame.display.set_caption("CartPole with DQN")
    clock = pygame.time.Clock()

    while not done:
        for event in pygame.event.get():
            if event.type == QUIT:
                print("Quit")
                pygame.quit()
                done = True
                return

        # Preprocess the state
        state_tensor = torch.Tensor(state).to(device)
        action = loaded_online_net.get_action(state_tensor)
        
        # Take the action in the environment
        # next_state, reward, done, _, _ = env.step(action)
        next_state, reward, terminated, truncated,_ = env.step(action)
        done = terminated or truncated
        print("done", done)
        done = False
        state = next_state

        # Render the environment
        env.render()
        
        # Limit the frame rate
        clock.tick(60)

    env.close()
    pygame.quit()

# %% [markdown]
# # Configuration

# %%
env_name = 'CartPole-v1'
goal_score = 200
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Play the game

# %%
# Test the function
play_game_with_model('train_10000e_2xep', load_best = False)
# Out:
# done False
# done False
# done False
# done False
# done False
# done False
# done False
# done False
# done False
# done False
# done False
# done True
# done True
# done True
# done True
# /opt/anaconda3/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:180: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# done True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Test the function
# ----> 2 play_game_with_model('train_10000e_2xep', load_best = False)
#
# Cell In[3], line 50, in play_game_with_model(model_name, load_best)
#      47 state = next_state
#      49 # Render the environment
# ---> 50 env.render()
#      52 # Limit the frame rate
#      53 clock.tick(60)
#
# File /opt/anaconda3/lib/python3.11/site-packages/gymnasium/core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File /opt/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
